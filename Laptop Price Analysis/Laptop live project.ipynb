# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#1.How can the dataset be imported into .ipynb code using the pandas library?

# %%
data=pd.read_csv(r'C:\Users\HP\Downloads\Laptop Data (2) (1).csv')

# %%
data
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %%
#2. Considering the nature of the dataset, would it be more suitable to employ Supervised or Unsupervised Machine Learning techniques?

# %%
#Supervised
# Labeled dataset: Target variable/response variable is present.
# Predictive modeling: Predict continuous (regression) or categorical (classification) outcomes.
#Examples: Predicting house prices

# %%
#3.If Supervised learning is deemed appropriate, what type of problem statement does it represent - Regression or Classification?

# %%
#regression type

# %%
#4.What methods can be employed to assess the quality of the data, including its shape and data types?

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (1020, 19)

# %%
#5. How can null values within the dataset be identified and handled effectively?

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    1020 non-null   object
#  1   Brand                   1020 non-null   object
#  2   Price                   1020 non-null   int64
#  3   Rating                  1020 non-null   float64
#  4   Processor_brand         1020 non-null   object
#  5   Processor_gen           891 non-null    float64
#  6   Core_per_processor      1008 non-null   float64
#  7   Energy_Efficient_Units  1020 non-null   int64
#  8   RAM_GB                  1020 non-null   int64
#  9   RAM_type                998 non-null    object
#  10  Storage_capacity_GB     1020 non-null   int64
#  11  Storage_type            1020 non-null   object
#  12  Graphics_brand          1018 non-null   object
#  13  Display_size_inches     1020 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Name                        0
# Brand                       0
# Price                       0
# Rating                      0
# Processor_brand             0
# Processor_gen             129
# Core_per_processor         12
# Energy_Efficient_Units      0
# RAM_GB                      0
# RAM_type                   22
# Storage_capacity_GB         0
# Storage_type                0
# Graphics_brand              2
# Display_size_inches         0
# Horizontal_pixel            0
# Vertical_pixel              0
# Touch_screen                0
# Operating_system            0
# dtype: int64

# %%
data['Processor_gen'].unique()
# Out:
# array([ 5.,  7., 12., 11., 14., nan, 13.,  6.,  3.,  8., 10.,  1.,  9.,
#         4.])

# %%
data['Processor_gen'].mean()
# Out:
# 10.450056116722783

# %%
data['Processor_gen']=data['Processor_gen'].fillna(10.0)

# %%
data.isnull().sum()
# Out:
# Name                       0
# Brand                      0
# Price                      0
# Rating                     0
# Processor_brand            0
# Processor_gen              0
# Core_per_processor        12
# Energy_Efficient_Units     0
# RAM_GB                     0
# RAM_type                  22
# Storage_capacity_GB        0
# Storage_type               0
# Graphics_brand             2
# Display_size_inches        0
# Horizontal_pixel           0
# Vertical_pixel             0
# Touch_screen               0
# Operating_system           0
# dtype: int64

# %%
data['Core_per_processor'].unique()
# Out:
# array([ 6.,  4., 12.,  2., 10., 24.,  8., 16., 14., 20., nan, 11.,  5.])

# %%
data['Core_per_processor']=data['Core_per_processor'].fillna(method='backfill')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_736\1642617023.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Core_per_processor']=data['Core_per_processor'].fillna(method='backfill')

# %%
data.isnull().sum()
# Out:
# Name                       0
# Brand                      0
# Price                      0
# Rating                     0
# Processor_brand            0
# Processor_gen              0
# Core_per_processor         0
# Energy_Efficient_Units     0
# RAM_GB                     0
# RAM_type                  22
# Storage_capacity_GB        0
# Storage_type               0
# Graphics_brand             2
# Display_size_inches        0
# Horizontal_pixel           0
# Vertical_pixel             0
# Touch_screen               0
# Operating_system           0
# dtype: int64

# %%
data['RAM_type'].mode()
# Out:
# 0    DDR4
# Name: RAM_type, dtype: object

# %%
data['RAM_type']=data['RAM_type'].fillna('DDR4')

# %%
data.isnull().sum()
# Out:
# Name                      0
# Brand                     0
# Price                     0
# Rating                    0
# Processor_brand           0
# Processor_gen             0
# Core_per_processor        0
# Energy_Efficient_Units    0
# RAM_GB                    0
# RAM_type                  0
# Storage_capacity_GB       0
# Storage_type              0
# Graphics_brand            2
# Display_size_inches       0
# Horizontal_pixel          0
# Vertical_pixel            0
# Touch_screen              0
# Operating_system          0
# dtype: int64

# %%
data['Graphics_brand'].mode()
# Out:
# 0    Intel
# Name: Graphics_brand, dtype: object

# %%
data['Graphics_brand']=data['Graphics_brand'].fillna('Intel')

# %%
data.isnull().sum()
# Out:
# Name                      0
# Brand                     0
# Price                     0
# Rating                    0
# Processor_brand           0
# Processor_gen             0
# Core_per_processor        0
# Energy_Efficient_Units    0
# RAM_GB                    0
# RAM_type                  0
# Storage_capacity_GB       0
# Storage_type              0
# Graphics_brand            0
# Display_size_inches       0
# Horizontal_pixel          0
# Vertical_pixel            0
# Touch_screen              0
# Operating_system          0
# dtype: int64

# %%
#6.Appropriate form of analysis should be presented and descripted in form of comments headings and analysis?

# %%
data.describe()
# Out:
#                Price       Rating  Processor_gen  Core_per_processor  \
# count    1020.000000  1020.000000    1020.000000         1020.000000
# mean    82063.474510     4.373676      10.393137            8.561765
# std     66502.150607     0.233295       2.776488            4.374418
# min      8000.000000     3.950000       1.000000            2.000000
# 25%     43990.000000     4.200000      10.000000            6.000000
# 50%     63689.500000     4.350000      12.000000            8.000000
# 75%     94990.000000     4.550000      13.000000           10.000000
# max    599990.000000     4.750000      14.000000           24.000000
#
#        Energy_Efficient_Units       RAM_GB  Storage_capacity_GB  \
# count             1020.000000  1020.000000          1020.000000
# mean                 0.043137    13.992157           627.733333
# std                  0.203266     7.189564           316.911679
# min                  0.000000     2.000000            32.000000
# ...

# %%
#7. What techniques can be utilized to detect and eliminate any outliers present in the dataset?

# %%
plt.boxplot(data['Energy_Efficient_Units']);

# %%
mean=data['Energy_Efficient_Units'].mean()

# %%
mean
# Out:
# 0.043137254901960784

# %%
std=data['Energy_Efficient_Units'].std()

# %%
std
# Out:
# 0.20326568560475508

# %%
data['zScore']=(data['Energy_Efficient_Units']-mean)/std

# %%
data[(data['zScore']<-3) | (data['zScore']>3)]
# Out:
#                                                   Name    Brand   Price  \
# 26   Samsung Galaxy Book 4 Ultra Laptop (Intel Core...  Samsung  299999
# 36   Lenovo IdeaPad Slim 5 ‎16IMH9 83DC0042IN Lapto...   Lenovo   75990
# 43   HP Envy x360 14-fc0105TU Laptop (Intel Core Ul...       HP   96999
# 75   Lenovo IdeaPad Slim 5 83DA0049IN Laptop (Intel...   Lenovo   76990
# 81   Samsung Galaxy Book 4 Pro 360 Laptop (Intel Co...  Samsung  199990
# 93   HP Envy x360 ‎14-fc0100TU Laptop (Intel Core U...       HP  133999
# 107  Lenovo IdeaPad Slim 5 14IMH9 83DA0043IN Laptop...   Lenovo   79990
# 108  HP Omen 14-fb0089TX Gaming Laptop (Intel Core ...       HP  175999
# 147  Xiaomi Redmi Book Pro 16 2024 Laptop (Intel Co...   Xiaomi   69990
# 148  Xiaomi Redmi Book Pro 14 2024 Laptop (Intel Co...   Xiaomi   59990
# 158  HP Envy x360 14-fc0078TU Laptop (Intel Core Ul...       HP  105990
# 159  Asus Zenbook 14 OLED UX3405 Laptop (Intel Core...     Asus  149990
# ...

# %%
data[~((data['zScore']<-3) | (data['zScore']>3))]
# Out:
#                                                    Name    Brand   Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP   50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo   26690
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP   37012
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung   69990
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno   23990
# ...                                                 ...      ...     ...
# 1015              MSI Creator Z17 HX Studio A13V Laptop      MSI  247999
# 1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI  292990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP   58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus   54999
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell   94490
#
#       Rating Processor_brand  Processor_gen  Core_per_processor  \
# ...

# %%
plt.boxplot(data[~((data['zScore']<-3) | (data['zScore']>3))]['Energy_Efficient_Units']);

# %%
#8.In cases where categorical variables are present, how can they be encoded using appropriate techniques?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    1020 non-null   object
#  1   Brand                   1020 non-null   object
#  2   Price                   1020 non-null   int64
#  3   Rating                  1020 non-null   float64
#  4   Processor_brand         1020 non-null   object
#  5   Processor_gen           1020 non-null   float64
#  6   Core_per_processor      1020 non-null   float64
#  7   Energy_Efficient_Units  1020 non-null   int64
#  8   RAM_GB                  1020 non-null   int64
#  9   RAM_type                1020 non-null   object
#  10  Storage_capacity_GB     1020 non-null   int64
#  11  Storage_type            1020 non-null   object
#  12  Graphics_brand          1020 non-null   object
#  13  Display_size_inches     1020 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data[['Name']]=data[['Name']].apply(enc.fit_transform)

# %%
data[['Brand','Processor_brand']]=data[['Brand','Processor_brand']].apply(enc.fit_transform)

# %%
data[['RAM_type','Storage_type','Graphics_brand']]=data[['RAM_type','Storage_type','Graphics_brand']].apply(enc.fit_transform)

# %%
data['Touch_screen'].unique()
# Out:
# array([ True, False])

# %%
data[['Touch_screen','Operating_system']]=data[['Touch_screen','Operating_system']].apply(enc.fit_transform)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    1020 non-null   int32
#  1   Brand                   1020 non-null   int32
#  2   Price                   1020 non-null   int64
#  3   Rating                  1020 non-null   float64
#  4   Processor_brand         1020 non-null   int32
#  5   Processor_gen           1020 non-null   float64
#  6   Core_per_processor      1020 non-null   float64
#  7   Energy_Efficient_Units  1020 non-null   int64
#  8   RAM_GB                  1020 non-null   int64
#  9   RAM_type                1020 non-null   int32
#  10  Storage_capacity_GB     1020 non-null   int64
#  11  Storage_type            1020 non-null   int32
#  12  Graphics_brand          1020 non-null   int32
#  13  Display_size_inches     1020 non-null   float64
# ...

# %%
#9.When necessary, how can the data be scaled using appropriate scaling techniques?

# %%
data.hist();

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
data1=sc.fit_transform(data)

# %%
pd.DataFrame(data1)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.239431 -0.096170 -0.476376 -0.315963 -1.708254 -1.943385 -0.585911
# 1     1.112249  0.850073 -0.833065  0.327315 -1.708254 -1.222697 -1.043339
# 2    -0.283581 -0.096170 -0.677776  1.185019  0.579386  0.579023 -0.585911
# 3     1.638657  1.796316 -0.181639  1.613871  0.579386  0.579023  0.786372
# 4     1.645449  1.954023 -0.873685 -0.530389  0.579386  0.218679 -1.500767
# ...        ...       ...       ...       ...       ...       ...       ...
# 1015  1.203946  1.007780  2.496414  0.327315  0.579386  0.939367  1.243800
# 1016  1.390736  1.007780  3.173281 -0.744815  0.579386  0.939367  1.243800
# 1017  0.215657 -0.096170 -0.349987  0.112889 -1.708254 -1.943385 -0.585911
# 1018 -1.105456 -1.200121 -0.407171 -0.530389 -1.708254 -1.222697 -0.585911
# 1019 -0.548483 -0.569292  0.186951 -1.388093  0.579386  0.939367  0.328945
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.kdeplot(data['Price'])
sns.kdeplot(data['RAM_type']);

# %%
data['sc_price']=sc.fit_transform(data[['Price']])
data['sc_ram_type']=sc.fit_transform(data[['RAM_type']])

# %%
data['sc_price'].mean()
# Out:
# -8.446402618716877e-17

# %%
data['sc_ram_type'].mean()
# Out:
# -7.314410515177502e-17

# %%
sns.kdeplot(data['sc_price'])
sns.kdeplot(data['sc_ram_type']);

# %%
#10.How can the dataset be divided into predictors and target variables?

# %%
x=data.drop('Price',axis=1)
y=data['Price']

# %%
#11.What is the recommended approach for dividing the dataset into training and testing sets?

# %%
from sklearn.model_selection import train_test_split

# %%
#12.Which machine learning model is most suitable for training the data, considering its characteristics?

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=20)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
#13.How can the accuracy of the trained model be evaluated to determine its effectiveness?

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
list=[LinearRegression,SVR,DecisionTreeRegressor,RandomForestRegressor,KNeighborsRegressor,LogisticRegression,KMeans,GaussianNB]

# %%
for i in list:
    k=KFold(n_splits=5)
    print(i)
    model=i()
    print(cross_val_score(model,x,y,cv=k).mean())
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
# 1.0
# <class 'sklearn.svm._classes.SVR'>
# -0.07980968026906306
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.9958990553714496
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.9945962663478213
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# 0.6543033614034657
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 0.016666666666666666
# <class 'sklearn.cluster._kmeans.KMeans'>
# -20409556.890812106
# <class 'sklearn.naive_bayes.GaussianNB'>
# 0.0823529411764706

# %%
#14.Proper approach to enhance the model by certain techniques must be done?

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_train,y_train)
# Out:
# 0.9997057753816015

# %%
model.score(x_test,y_test)
# Out:
# 0.9848216106840539

# %%
train=[]
test=[]
for i in range(0,200,10):
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=i)
    model=RandomForestRegressor(random_state=100)
    model.fit(x_train,y_train)
    train.append(model.score(x_train,y_train))
    test.append(model.score(x_test,y_test))

# %%
model=RandomForestRegressor(random_state=100)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=100)

# %%
model.score(x_train,y_train)
# Out:
# 0.9995668915487748

# %%
model.score(x_test,y_test)
# Out:
# 0.9879199761146876

# %%
test.index(max(test))
# Out:
# 6

# %%
train
# Out:
# [0.9985873838439153,
#  0.9993315399336269,
#  0.9995831681655064,
#  0.9996256537952516,
#  0.9990343722761957,
#  0.9990426604789964,
#  0.9991309600942304,
#  0.9991507032994473,
#  0.9989706530548299,
#  0.9989591605623321,
#  0.9994682532554042,
#  0.9993598742518921,
#  0.9990676770461459,
#  0.9993335504302199,
#  0.9988787882743227,
#  0.999677224904888,
#  0.999339993086115,
#  0.9995998805836661,
#  0.999231263552089,
#  0.9995668915487748]

# %%
test
# Out:
# [0.9993888555031663,
#  0.9986837819088598,
#  0.9828690010130081,
#  0.979455548840249,
#  0.9990326739588583,
#  0.9983944649189892,
#  0.999644909801293,
#  0.9996418775793259,
#  0.9992761955582505,
#  0.9981670406341349,
#  0.9995433860958903,
#  0.9990764606413602,
#  0.999494189806324,
#  0.9968794863187038,
#  0.995630339004463,
#  0.9773450725407867,
#  0.9995020219960198,
#  0.9779942495669277,
#  0.9995578737379642,
#  0.9879199761146876]

# %%
test.index(max(test))
# Out:
# 6

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=30)
model=RandomForestRegressor(random_state=100)
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.9996256537952516
# 0.979455548840249

# %%
dic={'n_estimators':[110,120,130],'max_depth':[3,4,5],'random_state':[10,15,16]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random=RandomizedSearchCV(RandomForestRegressor(),param_distributions=dic,n_iter=20,cv=k,verbose=2)

# %%
random.fit(x,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END .....max_depth=3, n_estimators=110, random_state=16; total time=   0.5s
# [CV] END .....max_depth=3, n_estimators=110, random_state=16; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=16; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=16; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=16; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=10; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=10; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=10; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=10; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=110, random_state=10; total time=   0.3s
# [CV] END .....max_depth=3, n_estimators=130, random_state=10; total time=   0.4s
# ...

# %%
random.best_params_
# Out:
# {'random_state': 15, 'n_estimators': 120, 'max_depth': 5}

# %%
model=RandomForestRegressor(random_state=15,n_estimators=120,max_depth=5)

# %%
model.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=120, random_state=15)

# %%
model.score(x,y)
# Out:
# 0.9986981621005866

# %%
pd.Series(model.feature_importances_,index=x.columns)
# Out:
# Name                      3.861932e-04
# Brand                     5.844941e-04
# Rating                    2.235211e-04
# Processor_brand           0.000000e+00
# Processor_gen             9.290493e-04
# Core_per_processor        3.807219e-05
# Energy_Efficient_Units    1.911586e-07
# RAM_GB                    3.774300e-04
# RAM_type                  7.091532e-05
# Storage_capacity_GB       1.345255e-04
# Storage_type              0.000000e+00
# Graphics_brand            1.994194e-05
# Display_size_inches       2.293293e-04
# Horizontal_pixel          1.584889e-04
# Vertical_pixel            3.719689e-04
# Touch_screen              1.118473e-05
# Operating_system          1.452388e-07
# zScore                    0.000000e+00
# sc_price                  9.963977e-01
# sc_ram_type               6.683801e-05
# dtype: float64

# %%
plt.figure(figsize=(10,10))

# %%
sns.heatmap(data.corr(),annot=True);

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_train,model.predict(x_train))
# Out:
# 750.0982254010955

# %%
(mean_squared_error(y_train,model.predict(x_train)))*(1/2)
# Out:
# 1055960.6861903246

# %%
r2_score(y_train,model.predict(x_train))
# Out:
# 0.9995047539117559
